# %% [markdown]
# # Original datasets are loaded as
# ![image.png](attachment:image.png)
#
# they have their own validations and processors:
#
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Dry run
# !!! To run this, you need an src/.env file with specified LOG_FOLDER, INPUT_FOLDER, OUTPUT_FOLDER
#
# After running the script on the original datasets we recieve the output datasets with all required modifications
#
# ![image.png](attachment:image.png)
#
# We have very comprehensive log system literally for every step of the process
#
# ![image-2.png](attachment:image-2.png)
#
# We can see all types of operations and errors there:
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Using validation sets
# I set INPUT_FOLDER as validation_sets
#
# ![image.png](attachment:image.png)
#
# after running src/main
# We got input
# ```
# FILE:INFO - Reading input files
# FILE:INFO - Reading titanic_testfile5.xlsx
# FILE:SUCCESS - Read 893 rows from titanic_testfile5.xlsx
# FILE:INFO - Reading Chicago_crime_testfile2.xlsx
# FILE:SUCCESS - Read 1000 rows from Chicago_crime_testfile2.xlsx
# FILE:INFO - Reading titanic_testfile1.xlsx
# FILE:SUCCESS - Read 891 rows from titanic_testfile1.xlsx
# FILE:INFO - Reading titanic_testfile2.xlsx
# FILE:SUCCESS - Read 891 rows from titanic_testfile2.xlsx
# FILE:INFO - Reading Chicago_crime_testfile1.xlsx
# FILE:SUCCESS - Read 1000 rows from Chicago_crime_testfile1.xlsx
# FILE:INFO - Reading Chicago_crime_testfile4.xlsx
# FILE:SUCCESS - Read 1000 rows from Chicago_crime_testfile4.xlsx
# FILE:INFO - Reading iris_testfile1.xlsx
# FILE:SUCCESS - Read 149 rows from iris_testfile1.xlsx
# FILE:INFO - Reading iris_testfile3.xlsx
# FILE:SUCCESS - Read 149 rows from iris_testfile3.xlsx
# FILE:INFO - Reading Chicago_crime_testfile3.xlsx
# FILE:SUCCESS - Read 1000 rows from Chicago_crime_testfile3.xlsx
# FILE:INFO - Reading iris_testfile2.xlsx
# FILE:SUCCESS - Read 149 rows from iris_testfile2.xlsx
# FILE:INFO - Reading titanic_testfile4.xlsx
# FILE:SUCCESS - Read 891 rows from titanic_testfile4.xlsx
# FILE:INFO - Reading titanic_testfile3.xlsx
# FILE:SUCCESS - Read 891 rows from titanic_testfile3.xlsx
#
# VALIDATION:INFO - Validating dataset titanic_testfile5.xlsx-TITANIC
# VALIDATION:ERROR - SEVERE: Column 'PassengerId' must have unique values but contains duplicates.
# VALIDATION:ERROR - SEVERE: Column 'Sex' contains values outside allowed set {'female', 'male'}.
# VALIDATION:WARNING - SAFE: Column 'Age' contains NULL values
# VALIDATION:ERROR - SEVERE: Column 'Age' contains values greater than 120.
# VALIDATION:WARNING - SAFE: Column 'Cabin' contains NULL values
# VALIDATION:WARNING - SAFE: Column 'Embarked' contains NULL values
#
# VALIDATION:INFO - Validating dataset Chicago_crime_testfile2.xlsx-CHICAGO
# VALIDATION:ERROR - SEVERE: Column 'date' contains values that are not of type <class 'pandas._libs.tslibs.timestamps.Timestamp'>.
# VALIDATION:WARNING - SAFE: Column 'location_description' contains NULL values
# VALIDATION:ERROR - SEVERE: Column 'updated_on' contains values that are not of type <class 'pandas._libs.tslibs.timestamps.Timestamp'>.
#
# VALIDATION:INFO - Validating dataset titanic_testfile1.xlsx-TITANIC
# VALIDATION:ERROR - SEVERE: Column 'Survived' contains values outside allowed set {0, 1}.
# VALIDATION:ERROR - SEVERE: Column 'Pclass' contains values that are not of type <class 'int'>.
# VALIDATION:ERROR - SEVERE: Column 'Pclass' contains values outside allowed set {1, 2, 3}.
# VALIDATION:WARNING - SAFE: Column 'Age' contains NULL values
# VALIDATION:ERROR - SEVERE: Column 'Age' contains values less than 0.
# VALIDATION:WARNING - SAFE: Column 'Cabin' contains NULL values
# VALIDATION:WARNING - SAFE: Column 'Embarked' contains NULL values
#
# VALIDATION:INFO - Validating dataset titanic_testfile2.xlsx-TITANIC
# VALIDATION:WARNING - SAFE: Column 'Age' contains NULL values
# VALIDATION:ERROR - SEVERE: Column 'Cabin' contains values that are not of type <class 'str'>.
# VALIDATION:WARNING - SAFE: Column 'Cabin' contains NULL values
# VALIDATION:WARNING - SAFE: Column 'Embarked' contains NULL values
# VALIDATION:ERROR - SEVERE: Column 'Embarked' contains values outside allowed set {'Q', 'C', 'S'}.
#
# VALIDATION:INFO - Validating dataset Chicago_crime_testfile1.xlsx-CHICAGO
# VALIDATION:ERROR - SEVERE: Column 'date' contains values that are not of type <class 'pandas._libs.tslibs.timestamps.Timestamp'>.
# VALIDATION:WARNING - SAFE: Column 'location_description' contains NULL values
# VALIDATION:ERROR - SEVERE: Column 'updated_on' contains values that are not of type <class 'pandas._libs.tslibs.timestamps.Timestamp'>.
#
# VALIDATION:INFO - Validating dataset Chicago_crime_testfile4.xlsx-CHICAGO
# VALIDATION:ERROR - SEVERE: Column 'date' contains values that are not of type <class 'pandas._libs.tslibs.timestamps.Timestamp'>.
# VALIDATION:WARNING - SAFE: Column 'primary_type' contains NULL values
# VALIDATION:WARNING - SAFE: Column 'description' contains NULL values
# VALIDATION:WARNING - SAFE: Column 'location_description' contains NULL values
# VALIDATION:ERROR - SEVERE: Column 'district' contains values that are not of type <class 'int'>.
# VALIDATION:ERROR - SEVERE: Column 'district' contains values less than 0.
# VALIDATION:ERROR - SEVERE: Column 'ward' contains values that are not of type <class 'int'>.
# VALIDATION:ERROR - SEVERE: Column 'ward' contains values less than 0.
# VALIDATION:ERROR - SEVERE: Column 'updated_on' contains values that are not of type <class 'pandas._libs.tslibs.timestamps.Timestamp'>.
#
# VALIDATION:INFO - Validating dataset iris_testfile1.xlsx-IRIS
# VALIDATION:ERROR - SEVERE: Column 'Species' contains values outside allowed set {'Iris-versicolor', 'Iris-virginica', 'Iris-setosa'}.
#
# VALIDATION:INFO - Validating dataset iris_testfile3.xlsx-IRIS
# VALIDATION:ERROR - SEVERE: Column 'Petal Length' contains values less than 0.
#
# VALIDATION:INFO - Validating dataset Chicago_crime_testfile3.xlsx-CHICAGO
# VALIDATION:ERROR - SEVERE: Column 'date' contains values that are not of type <class 'pandas._libs.tslibs.timestamps.Timestamp'>.
# VALIDATION:WARNING - SAFE: Column 'location_description' contains NULL values
# VALIDATION:ERROR - SEVERE: Column 'arrest' contains values that are not of type <class 'bool'>.
# VALIDATION:ERROR - SEVERE: Column 'domestic' contains values that are not of type <class 'bool'>.
# VALIDATION:ERROR - SEVERE: Column 'updated_on' contains values that are not of type <class 'pandas._libs.tslibs.timestamps.Timestamp'>.
#
# VALIDATION:INFO - Validating dataset iris_testfile2.xlsx-IRIS
#
# VALIDATION:INFO - Validating dataset titanic_testfile4.xlsx-TITANIC
# VALIDATION:WARNING - SAFE: Column 'Age' contains NULL values
# VALIDATION:WARNING - SAFE: Column 'Cabin' contains NULL values
# VALIDATION:WARNING - SAFE: Column 'Embarked' contains NULL values
#
# VALIDATION:INFO - Validating dataset titanic_testfile3.xlsx-TITANIC
# VALIDATION:WARNING - SAFE: Column 'Age' contains NULL values
# VALIDATION:WARNING - SAFE: Column 'Cabin' contains NULL values
# VALIDATION:WARNING - SAFE: Column 'Embarked' contains NULL values
# VALIDATION:ERROR - There are severe errors in datasets: titanic_testfile5.xlsx-TITANIC, Chicago_crime_testfile2.xlsx-CHICAGO, titanic_testfile1.xlsx-TITANIC, titanic_testfile2.xlsx-TITANIC, Chicago_crime_testfile1.xlsx-CHICAGO, Chicago_crime_testfile4.xlsx-CHICAGO, iris_testfile1.xlsx-IRIS, iris_testfile3.xlsx-IRIS, Chicago_crime_testfile3.xlsx-CHICAGO
# FILE:ERROR - Error reading files: There are severe errors in datasets: titanic_testfile5.xlsx-TITANIC, Chicago_crime_testfile2.xlsx-CHICAGO, titanic_testfile1.xlsx-TITANIC, titanic_testfile2.xlsx-TITANIC, Chicago_crime_testfile1.xlsx-CHICAGO, Chicago_crime_testfile4.xlsx-CHICAGO, iris_testfile1.xlsx-IRIS, iris_testfile3.xlsx-IRIS, Chicago_crime_testfile3.xlsx-CHICAGO
# ```

# %% [markdown]
# This output clearly explains what is wrong with each dataset and as long as there are severe errors it stops the program.
